# %%
import requests
import pandas as pd

# %%
requests.get("https://api.themoviedb.org/3/movie/popular?api_key=97db409aa2ba6c5acb71165d480c8777&language=en-US&page=1")
# Out:
# <Response [200]>

# %%
response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=97db409aa2ba6c5acb71165d480c8777&language=en-US&page=1").json()

# %%
#putting data into data frame
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

for i in response["results"]:
    popularity.append(i["popularity"])
    vote_count.append(i["vote_count"])
    original_language.append(i["original_language"])
    title.append(i["title"])
    vote_average.append(i["vote_average"])
    overview.append(i["overview"])
    release_date.append(i["release_date"])
    
d={"title":title, "overview":overview,"priginal language":original_language, "release_date":release_date,"popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}

df=pd.DataFrame(d)

# %%
df
# Out:
#                                                 title  \
# 0                                     Badland Hunters
# 1                                       Sixty Minutes
# 2                                               Wonka
# 3                                         The Marvels
# 4                                                Lift
# 5                                       The Beekeeper
# 6                        Aquaman and the Lost Kingdom
# 7                                           Migration
# 8                                                Wish
# 9   The Hunger Games: The Ballad of Songbirds & Sn...
# 10                                    The Family Plan
# 11             Rebel Moon - Part One: A Child of Fire
# 12                                      One More Shot
# 13                             The Tiger's Apprentice
# 14                                          Role Play
# 15                                     The Bricklayer
# ...

# %%
final=pd.DataFrame()

for j in range (1,500):
    response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=97db409aa2ba6c5acb71165d480c8777&language=en-US&page={}".format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]

    for i in response["results"]:
        popularity.append(i["popularity"])
        vote_count.append(i["vote_count"])
        original_language.append(i["original_language"])
        title.append(i["title"])
        vote_average.append(i["vote_average"])
        overview.append(i["overview"])
        release_date.append(i["release_date"])

    d={"title":title, "overview":overview,"priginal language":original_language, "release_date":release_date,"popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}

    df=pd.DataFrame(d)

    final = pd.concat([final, df], ignore_index=True)

# %%
final
# Out:
#                                  title  \
# 0                      Badland Hunters
# 1                        Sixty Minutes
# 2                                Wonka
# 3                          The Marvels
# 4                                 Lift
# ...                                ...
# 9975  Mishima: A Life in Four Chapters
# 9976                  Strange but True
# 9977                        Mr. Church
# 9978                       Pitch Black
# 9979                        Rio Grande
#
#                                                overview priginal language  \
# 0     After a deadly earthquake turns Seoul into a l...                ko
# 1     Desperate to keep custody of his daughter, a m...                de
# 2     Willy Wonka – chock-full of ideas and determin...                en
# 3     Carol Danvers, aka Captain Marvel, has reclaim...                en
# 4     An international heist crew, led by Cyrus Whit...                en
# ...

# %%
final.to_csv("Movie Dataset Final.csv")
